# %% [markdown]
# # 🎯 Project Goal
#
# ## 🔍 Objective
# Investigate **top-paying roles** and **in-demand skills** in the **data science industry**.
#
# ## 🧠 Approach
# - Use **Python** to explore and analyze a **real-world job postings dataset**
# - Identify trends in:
#   - Job roles
#   - Required skills
#   - Salary ranges
#   - Benefits and job conditions
#
# ## 💼 Who This Is For
# **Job seekers in data & analytics** who want to:
# - Understand which roles pay the most
# - Learn which skills are most valuable
# - Make **data-driven career decisions**
#
# ## 📊 Outcome
# Actionable insights that help job seekers:
# - Target high-paying opportunities
# - Focus on the most rewarding skills
# - Align learning paths with market demand

# %% [markdown]
# # ❓ Questions to Answer
#
# ### 1️⃣ What are the most demanded skills for the **top 3 most popular data roles**?
# - Identify core skills required across the most common roles in the data industry.
#
# ### 2️⃣ How are **in-demand skills trending** for **Data Analysts**?
# - Analyze how demand for specific skills changes over time.
#
# ### 3️⃣ How well do **jobs and skills pay** for **Data Analysts**?
# - Compare salaries across roles
# - Evaluate which skills command higher compensation
#
# ### 4️⃣ What is the **most optimal skill to learn** for **Data Analysts**?
# > 📈 High Demand **AND** 💰 High Paying
# - Identify skills that maximize both job opportunities and salary potential.
#
# ---
#
# ## 🌎 Scope of Analysis
# - Primary focus: **🇺🇸 United States – Data Analyst roles**
# - The analysis framework can be adapted to:
#   - Other countries
#   - Other data roles (Data Scientist, Data Engineer, etc.)

# %% [markdown]
# Exploratory Data Analysis for all Data Roles

# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# Job roles to explore

# %%
df_plot = df['job_title_short'].value_counts().to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_title_short', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Number of Jobs per Job Title')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# Countries to Explore

# %%
df_plot = df['job_country'].value_counts().to_frame().head(20)

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_country', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Number of Jobs per Country')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# Companies to Explore

# %%
df_plot = df['company_name'].value_counts().to_frame()[1:].head(20)

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='company_name', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Number of Jobs per Company')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# Job Opportunities

# %%
dict_column = {
    'job_work_from_home': 'Work from Home Offered',
    'job_no_degree_mention': 'Degree Requirement',
    'job_health_insurance': 'Health Insurance Offered'
}

fig, ax = plt.subplots(1, 3, figsize=(11, 3.5))

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df[column].value_counts(), labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
    ax[i].set_title(title)

plt.show()

# %% [markdown]
# Exploratory Data Analysis for Data Analysts in the India

# %%
df_DA_ind = df[(df['job_country'] == 'India') & (df['job_title_short'] == 'Data Analyst')]

# %%
df_plot = df_DA_ind['job_location'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_location', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts of Job Locations for Data Analyst in the India')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# Job Opportunities

# %%
fig, ax = plt.subplots(1, 3)
fig.set_size_inches((12, 5))

for i, (column, title) in enumerate(dict_column.items()):
    counts = df_DA_ind[column].value_counts()
    
    ax[i].pie(
        counts.values,
        labels=counts.index.astype(str),
        autopct='%1.1f%%',
        startangle=90
    )
    
    ax[i].set_title(title)

plt.show()

# %% [markdown]
# Companies to Explore:

# %%
df_plot = df_DA_ind['company_name'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='company_name', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts of Companies for Data Analyst in the US')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()
